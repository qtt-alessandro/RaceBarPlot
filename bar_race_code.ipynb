# %%
import pandas as pd
import bar_chart_race as bcr

# %% [markdown]
# ### Per generare il raceplot, il dataset deve avere la seguente struttura:
#
# - Datetime come indici del dataset
# - Elementi (in questo caso hashtag come colonne)
# - Cumulative sum sulle colonne.

# %%
test_dict = {'date': ['2022-04-07 00:00:00+00:00','2022-04-08 00:00:00+00:00','2022-04-09 00:00:00+00:00', '2022-04-10 00:00:00+00:00', '2022-04-11 00:00:00+00:00', '2022-04-12 00:00:00+00:00', '2022-04-13 00:00:00+00:00'],
         '#Ukraine':         [2369, 4361, 6449, 8497, 9929, 11739, 14325],
         '#Russian':         [2232, 5434, 6668, 7148, 7924, 8251, 8435], 
         '#Russia':          [1513, 2645, 5991, 6427, 7203, 9093, 15223], 
         '#dogsofukraine':   [1459, 2133, 2368, 2434, 2462, 2462, 2462],
         '#BuchaMassacre':   [1297, 2046, 2504, 2763, 2974, 3160, 4038],
         '#RussianArmy':     [882,  1373, 1457, 1457, 1457, 1522, 1554],
         '#Putin':           [607,  869,  1424, 1824, 1997, 2220, 2327],
         '#UkraineWar':      [412,  610,  905,  905, 1092, 1280,  1401],
         '#StandWithUkraine':[411,  609,  904,  904,  1091, 1279, 1400],
         '#Mariupol':        [402,  930,  1282, 1715, 1939, 2318, 2620],
         '#borodyanka':      [391,  391,  616,  750,  791,  791, 791], 
         '#Ukrainian':       [378,  1720, 2319, 2451, 2451, 2709, 2803]}

test = pd.DataFrame(test_dict)
test['date'] = pd.to_datetime(test['date'])
test.set_index('date', inplace=True)

# %%
test
# Out:
#                            #Ukraine  #Russian  #Russia  #dogsofukraine  \
# date
# 2022-04-07 00:00:00+00:00      2369      2232     1513            1459
# 2022-04-08 00:00:00+00:00      4361      5434     2645            2133
# 2022-04-09 00:00:00+00:00      6449      6668     5991            2368
# 2022-04-10 00:00:00+00:00      8497      7148     6427            2434
# 2022-04-11 00:00:00+00:00      9929      7924     7203            2462
# 2022-04-12 00:00:00+00:00     11739      8251     9093            2462
# 2022-04-13 00:00:00+00:00     14325      8435    15223            2462
#
#                            #BuchaMassacre  #RussianArmy  #Putin  #UkraineWar  \
# date
# 2022-04-07 00:00:00+00:00            1297           882     607          412
# 2022-04-08 00:00:00+00:00            2046          1373     869          610
# 2022-04-09 00:00:00+00:00            2504          1457    1424          905
# ...

# %%
#pip install bar_chart_race 
#sudo apt get update 
#sudo apt install ffmpeg

# %%
bcr.bar_chart_race(
    df=test,
    filename='/home/alessandro/Git/RaceBarPlot/top_twitter_hashtag.mp4',
    orientation='h',
    sort='desc',
    n_bars=12,
    fixed_order=False,
    fixed_max=True,
    steps_per_period=100,
    interpolate_period=True,
    label_bars=True,
    bar_size=.95,
    period_label={'x': .99, 'y': .25, 'ha': 'right', 'va': 'center'},
    period_fmt='%B %d, %Y',
    period_summary_func=lambda v, r: {'x': .99, 'y': .18,
                                      's': f'Total Tweets: {v.nlargest(6).sum():,.0f}',
                                      'ha': 'right', 'size': 8, 'family': 'Courier New'},
    perpendicular_bar_func=None,
    period_length=4000,
    figsize=(5, 3),
    dpi=320,
    cmap='dark12',
    title='Top 12 Trending  Hashtag Related to #Bucha',
    title_size='',
    bar_label_size=7,
    tick_label_size=7,
    shared_fontdict={'family' : 'Helvetica', 'color' : '.1'},
    scale='linear',
    writer=None,
    fig=None,
    bar_kwargs={'alpha': .7},
    filter_column_colors=False)
# Out:
# findfont: Font family ['Helvetica'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Helvetica'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Helvetica'] not found. Falling back to DejaVu Sans.
# /home/alessandro/.local/lib/python3.10/site-packages/bar_chart_race/_make_chart.py:286: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(self.df_values.columns)
# /home/alessandro/.local/lib/python3.10/site-packages/bar_chart_race/_make_chart.py:287: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([max_val] * len(ax.get_xticks()))
# findfont: Font family ['Courier New'] not found. Falling back to DejaVu Sans.
